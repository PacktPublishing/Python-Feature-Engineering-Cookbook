# %%
import pandas as pd
import matplotlib.pyplot as plt
import featuretools as ft

# %%
# let's load the example data set from feature tools

data_dict = ft.demo.load_mock_customer()

data = data_dict["transactions"].merge(
    data_dict["sessions"]).merge(data_dict["customers"])

cols = ['customer_id',
        'transaction_id',
        'transaction_time',
        'amount',
        ]

data = data[cols]

data.head()
# Out:
#    customer_id  transaction_id    transaction_time  amount
# 0            2             298 2014-01-01 00:00:00  127.64
# 1            2               2 2014-01-01 00:01:05  109.48
# 2            2             308 2014-01-01 00:02:10   95.06
# 3            2             116 2014-01-01 00:03:15   78.92
# 4            2             371 2014-01-01 00:04:20   31.54

# %%
print('Number of customers: {}'.format(data['customer_id'].nunique()))
print('Number of transactions: {}'.format(data['transaction_id'].nunique()))
# Out:
# Number of customers: 5
# Number of transactions: 500

# %%
data.dtypes
# Out:
# customer_id                  int64
# transaction_id               int64
# transaction_time    datetime64[ns]
# amount                     float64
# dtype: object

# %%
# in order for feature tools to work, we need to create
# entity sets

es = ft.EntitySet(id="customer_data")

# entity set with the transactions
es.entity_from_dataframe(entity_id='transactions',
                         dataframe=data,
                         index="transaction_id",
                         time_index='transaction_time')

# display the entity set
es
# Out:
# Entityset: customer_data
#   Entities:
#     transactions [Rows: 500, Columns: 4]
#   Relationships:
#     No relationships

# %%
# now we indicate that within the entity set
# there is another table, with customer data,
# each customer identified with a unique
# customer id

es.normalize_entity(base_entity_id="transactions",
                    new_entity_id="customers",
                    index="customer_id")
# Out:
# Entityset: customer_data
#   Entities:
#     transactions [Rows: 500, Columns: 4]
#     customers [Rows: 5, Columns: 2]
#   Relationships:
#     transactions.customer_id -> customers.customer_id

# %% [markdown]
# ## Creating new features from the existing data - without aggregations

# %%
# featuretools automatically creates more fearures from those present in the data set
# for every single transaction, that is without aggregation

# the names in the below list, indicate featuretools to:
# 1) Create a feature from the datetime variable signalling
# if the transaction occurred on a weekend
# 2) Determines the cumulative transaction amount,
# 3) Determine the cumulative number of transactions,
# 4) Creates a new feature indicating the time since the previous transaction

# all of this operations occur at a transaction level, that is, transaction
# after transaction

transf_operations = ['is_weekend', 'cum_sum', 'cum_count','time_since_previous']

# set up the dfs from featuretools to return the previous features
# it is important to leave agg_primitives as an empty list, so that featuretools does not
# aggregate the data at a customer level as well

feature_matrix, features = ft.dfs(entityset=es,
                      target_entity="transactions",
                      agg_primitives=[],
                      trans_primitives=transf_operations,
                      verbose=True)

feature_matrix.head()
# Out:
# Built 8 features
# Elapsed: 00:00 | Progress: 100%|██████████████████████████████████████████████████████████████████
#                 customer_id  amount  IS_WEEKEND(transaction_time)  \
# transaction_id
# 298                       2  127.64                         False
# 2                         2  109.48                         False
# 308                       2   95.06                         False
# 116                       2   78.92                         False
# 371                       2   31.54                         False
#
#                 CUM_SUM(amount)  CUM_COUNT(customer_id)  \
# transaction_id
# 298                      127.64                       1
# 2                        237.12                       2
# 308                      332.18                       3
# 116                      411.10                       4
# 371                      442.64                       5
#
#                 TIME_SINCE_PREVIOUS(transaction_time)  \
# transaction_id
# 298                                               NaN
# 2                                                65.0
# 308                                              65.0
# 116                                              65.0
# 371                                              65.0
#
#                 customers.IS_WEEKEND(first_transactions_time)  \
# transaction_id
# 298                                                     False
# 2                                                       False
# 308                                                     False
# 116                                                     False
# 371                                                     False
#
#                 customers.TIME_SINCE_PREVIOUS(first_transactions_time)
# transaction_id
# 298                                                           NaN
# 2                                                             NaN
# 308                                                           NaN
# 116                                                           NaN
# 371                                                           NaN

# %%
# let's now extract information about date and time as well

# list with the operations to perform to extract new features from the 
# existing variables
operations = ['year', 'month', 'day', 'hour', 'minute', 'second',
             'is_weekend', 'cum_sum', 'time_since_previous']


# extract tge new features
feature_matrix, features = ft.dfs(entityset=es,
                      target_entity="transactions",
                      agg_primitives=[],
                      trans_primitives=None,
                      verbose=True)

feature_matrix.head()
# Out:
# Built 10 features
# Elapsed: 00:00 | Progress: 100%|██████████████████████████████████████████████████████████████████
#                 customer_id  amount  DAY(transaction_time)  \
# transaction_id
# 298                       2  127.64                      1
# 2                         2  109.48                      1
# 308                       2   95.06                      1
# 116                       2   78.92                      1
# 371                       2   31.54                      1
#
#                 YEAR(transaction_time)  MONTH(transaction_time)  \
# transaction_id
# 298                               2014                        1
# 2                                 2014                        1
# 308                               2014                        1
# 116                               2014                        1
# 371                               2014                        1
#
#                 WEEKDAY(transaction_time)  \
# transaction_id
# 298                                     2
# 2                                       2
# 308                                     2
# 116                                     2
# 371                                     2
#
#                 customers.DAY(first_transactions_time)  \
# transaction_id
# 298                                                  1
# 2                                                    1
# 308                                                  1
# 116                                                  1
# 371                                                  1
#
#                 customers.YEAR(first_transactions_time)  \
# transaction_id
# 298                                                2014
# 2                                                  2014
# 308                                                2014
# 116                                                2014
# 371                                                2014
#
#                 customers.MONTH(first_transactions_time)  \
# transaction_id
# 298                                                    1
# 2                                                      1
# 308                                                    1
# 116                                                    1
# 371                                                    1
#
#                 customers.WEEKDAY(first_transactions_time)
# transaction_id
# 298                                                      2
# 2                                                        2
# 308                                                      2
# 116                                                      2
# 371                                                      2

# %%
# original dataframe and derived feature_matrix should have
# same number of observations

data.shape, feature_matrix.shape
# Out:
# ((500, 4), (500, 10))

# %%
# if we don't indicate the operations to perform to create new features, featuretools will perform
# the default operations, which can be found here:

# https://docs.featuretools.com/en/stable/generated/featuretools.dfs.html#featuretools.dfs

# %%
# if we had more than 1 numeric feature in our dataframe, we could create new feautres by addition
# or multiplication as we did in recipe Combining multiple features with statistical operations of Chapter 9,
# Applying Mathematical Computations to Features

# for code on how to do that check this link:
# https://stackoverflow.com/questions/55155371/how-to-use-featuretools-to-create-features-for-a-single-table-with-no-immediate/55172142#55172142

# %%
# for more details in the types of features that we can create
# check the supported operations with the code below

primitives = ft.list_primitives()
pd.options.display.max_colwidth = 500
primitives[primitives['type'] == 'transform']
# Out:
#                                name       type  \
# 20                         absolute  transform
# 21                             isin  transform
# 22                         latitude  transform
# 23                        cum_count  transform
# 24                              and  transform
# 25                        not_equal  transform
# 26                           second  transform
# 27                modulo_by_feature  transform
# 28                divide_by_feature  transform
# 29                     greater_than  transform
# 30                 less_than_scalar  transform
# 31                        num_words  transform
# 32                        haversine  transform
# 33                              day  transform
# 34                        less_than  transform
# 35                     equal_scalar  transform
# 36                 multiply_numeric  transform
# 37  scalar_subtract_numeric_feature  transform
# 38                             year  transform
# 39            divide_numeric_scalar  transform
# 40                       time_since  transform
# 41            greater_than_equal_to  transform
# 42                             hour  transform
# 43          multiply_numeric_scalar  transform
# 44                          cum_max  transform
# 45                        longitude  transform
# 46                            equal  transform
# 47                 multiply_boolean  transform
# 48              time_since_previous  transform
# 49                         cum_mean  transform
# 50                          is_null  transform
# 51                              not  transform
# 52                 not_equal_scalar  transform
# 53                          weekday  transform
# 54                       percentile  transform
# 55                          cum_sum  transform
# 56                             diff  transform
# 57        less_than_equal_to_scalar  transform
# 58                 subtract_numeric  transform
# 59                   divide_numeric  transform
# 60                       is_weekend  transform
# 61     greater_than_equal_to_scalar  transform
# 62               less_than_equal_to  transform
# 63                   modulo_numeric  transform
# 64                            month  transform
# 65               add_numeric_scalar  transform
# 66              greater_than_scalar  transform
# 67                           negate  transform
# 68                               or  transform
# 69                      add_numeric  transform
# 70                             week  transform
# 71                   num_characters  transform
# 72          subtract_numeric_scalar  transform
# 73                           minute  transform
# 74            modulo_numeric_scalar  transform
# 75                          cum_min  transform
#
#                                                                     description
# 20                                     Computes the absolute value of a number.
# 21                    Determines whether a value is present in a provided list.
# 22                   Returns the first tuple value in a list of LatLong tuples.
# 23                                             Calculates the cumulative count.
# 24                                       Element-wise logical AND of two lists.
# 25              Determines if values in one list are not equal to another list.
# 26                                  Determines the seconds value of a datetime.
# 27                   Return the modulo of a scalar by each element in the list.
# 28                                   Divide a scalar by each value in the list.
# 29              Determines if values in one list are greater than another list.
# 30                           Determines if values are less than a given scalar.
# 31           Determines the number of words in a string by counting the spaces.
# 32            Calculates the approximate haversine distance between two LatLong
# 33                             Determines the day of the month from a datetime.
# 34                 Determines if values in one list are less than another list.
# 35                  Determines if values in a list are equal to a given scalar.
# 36                                    Element-wise multiplication of two lists.
# 37                         Subtract each value in the list from a given scalar.
# 38                                     Determines the year value of a datetime.
# 39                                 Divide each element in the list by a scalar.
# 40                 Calculates time from a value to a specified cutoff datetime.
# 41  Determines if values in one list are greater than or equal to another list.
# 42                                     Determines the hour value of a datetime.
# 43                               Multiply each element in the list by a scalar.
# 44                                           Calculates the cumulative maximum.
# 45                  Returns the second tuple value in a list of LatLong tuples.
# 46                  Determines if values in one list are equal to another list.
# 47                  Element-wise multiplication of two lists of boolean values.
# 48                         Compute the time since the previous entry in a list.
# 49                                              Calculates the cumulative mean.
# 50                                               Determines if a value is null.
# 51                                                     Negates a boolean value.
# 52              Determines if values in a list are not equal to a given scalar.
# 53                              Determines the day of the week from a datetime.
# 54                     Determines the percentile rank for each value in a list.
# 55                                               Calculates the cumulative sum.
# 56                   Compute the difference between the value in a list and the
# 57               Determines if values are less than or equal to a given scalar.
# 58                                       Element-wise subtraction of two lists.
# 59                                          Element-wise division of two lists.
# 60                                     Determines if a date falls on a weekend.
# 61            Determines if values are greater than or equal to a given scalar.
# 62     Determines if values in one list are less than or equal to another list.
# 63                                            Element-wise modulo of two lists.
# 64                                    Determines the month value of a datetime.
# 65                                      Add a scalar to each value in the list.
# 66                        Determines if values are greater than a given scalar.
# 67                                                     Negates a numeric value.
# 68                                        Element-wise logical OR of two lists.
# 69                                          Element-wise addition of two lists.
# 70                             Determines the week of the year from a datetime.
# 71                             Calculates the number of characters in a string.
# 72                             Subtract a scalar from each element in the list.
# 73                                  Determines the minutes value of a datetime.
# 74                   Return the modulo of each element in the list by a scalar.
# 75                                           Calculates the cumulative minimum.

# %% [markdown]
# ## Creating new features from the existing data - with aggregations
#
# These are the features we can create when we want a flattened view of our dataframe, that is one row per customer.

# %%
# differently from the previous case, here we want to aggregate
# the information at customer level, so we want a summary view of
# each customer

# first we aggregate only the existing variables
# that is the transaction amount

# we want the mean and maximum transaction amount per customer

feature_matrix, features = ft.dfs(entityset=es,
                      target_entity="customers",
                      agg_primitives=["mean", 'max'],
                      trans_primitives=[],
                      verbose=True)

# dataframe with the new features
feature_matrix
# Out:
# Built 2 features
# Elapsed: 00:00 | Progress: 100%|██████████████████████████████████████████████████████████████████
#              MEAN(transactions.amount)  MAX(transactions.amount)
# customer_id
# 2                            77.422366                    146.81
# 5                            80.375443                    149.02
# 4                            80.070459                    149.95
# 1                            71.631905                    139.43
# 3                            67.060430                    149.15

# %%
# now we will create a new feature as in the first part of the 
# notebook, and more specifically, we will create the feature
# time_since_previous transaction

# and aggregate the new feature together with the pre-existing
# variable transaction amount, all in one go

feature_matrix, features = ft.dfs(entityset=es,
                      target_entity="customers",
                      agg_primitives=["mean", 'max'],
                      trans_primitives=['time_since_previous'],
                      verbose=True)

# dataframe with the new features
feature_matrix
# Out:
# Built 5 features
# Elapsed: 00:00 | Progress: 100%|██████████████████████████████████████████████████████████████████
#              MEAN(transactions.amount)  MAX(transactions.amount)  \
# customer_id
# 2                            77.422366                    146.81
# 5                            80.375443                    149.02
# 4                            80.070459                    149.95
# 1                            71.631905                    139.43
# 3                            67.060430                    149.15
#
#              TIME_SINCE_PREVIOUS(first_transactions_time)  \
# customer_id
# 2                                                     NaN
# 5                                                  1040.0
# 4                                                   650.0
# 1                                                   975.0
# 3                                                  3315.0
#
#              MEAN(transactions.TIME_SINCE_PREVIOUS(transaction_time))  \
# customer_id
# 2                                                                65.0
# 5                                                                65.0
# 4                                                                65.0
# 1                                                                65.0
# 3                                                                65.0
#
#              MAX(transactions.TIME_SINCE_PREVIOUS(transaction_time))
# customer_id
# 2                                                               65.0
# 5                                                               65.0
# 4                                                               65.0
# 1                                                               65.0
# 3                                                               65.0

# %%
# note how the final dataframe contains as many rows as 
# different customers in the data set

data.shape, feature_matrix.shape
# Out:
# ((500, 4), (5, 5))

# %%
# and now let's create 2 new features and aggregate both
# together with the transaction amount

feature_matrix, features = ft.dfs(entityset=es,
                      target_entity="customers",
                      agg_primitives=["mean", 'max'],
                      trans_primitives=['cum_sum','time_since_previous'],
                      verbose=True)

# dataframe with the new features
feature_matrix
# Out:
# Built 9 features
# Elapsed: 00:00 | Progress: 100%|██████████████████████████████████████████████████████████████████
#              MEAN(transactions.amount)  MAX(transactions.amount)  \
# customer_id
# 2                            77.422366                    146.81
# 5                            80.375443                    149.02
# 4                            80.070459                    149.95
# 1                            71.631905                    139.43
# 3                            67.060430                    149.15
#
#              TIME_SINCE_PREVIOUS(first_transactions_time)  \
# customer_id
# 2                                                     NaN
# 5                                                  1040.0
# 4                                                   650.0
# 1                                                   975.0
# 3                                                  3315.0
#
#              MEAN(transactions.CUM_SUM(amount))  \
# customer_id
# 2                                  18794.182366
# 5                                  24258.206582
# 4                                  12455.024495
# 1                                  16566.784048
# 3                                  25387.640538
#
#              MEAN(transactions.TIME_SINCE_PREVIOUS(transaction_time))  \
# customer_id
# 2                                                                65.0
# 5                                                                65.0
# 4                                                                65.0
# 1                                                                65.0
# 3                                                                65.0
#
#              MAX(transactions.CUM_SUM(amount))  \
# customer_id
# 2                                     35101.22
# 5                                     34296.39
# 4                                     23418.09
# 1                                     31291.89
# 3                                     37539.86
#
#              MAX(transactions.TIME_SINCE_PREVIOUS(transaction_time))  \
# customer_id
# 2                                                               65.0
# 5                                                               65.0
# 4                                                               65.0
# 1                                                               65.0
# 3                                                               65.0
#
#              CUM_SUM(MAX(transactions.amount))  \
# customer_id
# 2                                       146.81
# 5                                       295.83
# 4                                       445.78
# 1                                       585.21
# 3                                       734.36
#
#              CUM_SUM(MEAN(transactions.amount))
# customer_id
# 2                                     77.422366
# 5                                    157.797809
# 4                                    237.868267
# 1                                    309.500172
# 3                                    376.560602

# %%
data.shape, feature_matrix.shape
# Out:
# ((500, 4), (5, 9))

# %% [markdown]
# ## Integrating user defined functions
#
# In the remaining lines, instead of using Featuretools pre-coded functions, we will create our own.

# %%
from featuretools.primitives import make_trans_primitive, make_agg_primitive
from featuretools.variable_types import Numeric

from scipy.signal import find_peaks


def find_no_peaks(column):
    peaks, _ = find_peaks(column)
    return len(peaks)


def find_no_valleys(column):
    valleys, _ = find_peaks(1 / column)
    return len(valleys)


FindNoPeaks = make_agg_primitive(function=find_no_peaks,
                                 input_types=[Numeric],
                                 return_type=Numeric)

FindNoValleys = make_agg_primitive(function=find_no_valleys,
                                   input_types=[Numeric],
                                   return_type=Numeric)

# %%
# and now let's use our 2 new aggregation functions with mean and max

feature_matrix, features = ft.dfs(entityset=es,
                      target_entity="customers",
                      agg_primitives=[FindNoPeaks, FindNoValleys, 'Mean', 'Max'],
                      trans_primitives=[],
                      verbose=True)

# dataframe with the new features
feature_matrix
# Out:
# Built 4 features
# Elapsed: 00:00 | Progress: 100%|██████████████████████████████████████████████████████████████████
#              FIND_NO_PEAKS(transactions.amount)  \
# customer_id
# 2                                          28.0
# 5                                          26.0
# 4                                          37.0
# 1                                          43.0
# 3                                          29.0
#
#              FIND_NO_VALLEYS(transactions.amount)  MEAN(transactions.amount)  \
# customer_id
# 2                                            29.0                  77.422366
# 5                                            26.0                  80.375443
# 4                                            38.0                  80.070459
# 1                                            42.0                  71.631905
# 3                                            29.0                  67.060430
#
#              MAX(transactions.amount)
# customer_id
# 2                              146.81
# 5                              149.02
# 4                              149.95
# 1                              139.43
# 3                              149.15
